# %%
# %pip install pandas
# %pip install matplotlib
# %pip install seaborn
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns
import matplotlib
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\Aadit\OneDrive\Desktop\Berkeley Lab work\Coevolutionary-Dynamics-Cryptic-Female-Choice\CSV data\run_2026-02-20T15-54-21\kbuffer_results_2026-02-20T15-54-21.csv')

# %%
df
# Out:
#      MeanMale  MeanFemale     SDMale   SDFemale       cor  MeanCount  \
# 0   50.207306   49.624759  10.397153  10.175689 -0.009254  49.902328
# 1   49.739468   49.866713  10.035500  10.132037  0.043090  49.576373
# 2   49.576716   49.654781   9.799040  10.061286  0.103275  49.154832
# 3   49.396344   49.609156   9.720098  10.154038  0.136916  48.736248
# 4   49.209952   49.518408   9.710986  10.123249  0.167645  48.392770
# ..        ...         ...        ...        ...       ...        ...
# 95  51.261838   51.672481  10.093599  11.340780  0.001197  23.714210
# 96  51.275963   51.724277  10.105322  11.350247  0.002636  23.608475
# 97  51.291491   51.773239  10.128348  11.396546  0.001117  23.446605
# 98  51.295546   51.729065  10.090942  11.422248 -0.006068  23.334987
# 99  51.248873   51.766898  10.073406  11.441586  0.003111  23.236762
#
#       SDCount        is       int     BMale  ...       GFS    a   MeanRSC  \
# ...

# %%
sns.lineplot(data=df,x = 'Generation',y='population')
# Out:
# <Axes: xlabel='Generation', ylabel='population'>

# %%
sns.lineplot(data=df,x = 'Generation',y='MeanRSC')
# Out:
# <Axes: xlabel='Generation', ylabel='MeanRSC'>

# %%
correlation_coefficient = df['MeanRSC'].corr(df['MeanMates'])
correlation_coefficient
correlation_coefficient2 = df['offspring'].corr(df['MeanMates'])
print('Mates to offspring corelation :', correlation_coefficient2, ' corelation Mates to MEANRSC :', correlation_coefficient)
# Out:
# Mates to offspring corelation : 0.5377877523966562  corelation Mates to MEANRSC : 0.9996801376738491

# %%
sns.lineplot(data=df,x = 'Generation',y=np.log10(df['offspring']))
# Out:
# <Axes: xlabel='Generation', ylabel='offspring'>
