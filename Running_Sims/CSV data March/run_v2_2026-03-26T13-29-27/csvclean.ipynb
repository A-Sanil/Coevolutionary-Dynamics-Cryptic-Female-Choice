# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/aadityasanil/Desktop/Lab Testing Feb 19/Coevolutionary-Dynamics-Cryptic-Female-Choice/Running_Sims/CSV data March/run_v2_2026-03-26T13-29-27/kbuffer_v2_results_2026-03-26T13-29-27.csv")

# %%
print(df.columns)
# Out:
# Index(['MeanMale', 'MeanFemale', 'SDMale', 'SDFemale', 'cor', 'MeanCount',
#        'SDCount', 'is', 'int', 'BMale', 'GMale', 'BFemale', 'GFemale',
#        'BSperm', 'GSperm', 'GMF', 'GMS', 'GFS', 'a', 'MeanRSC', 'Generation',
#        'MeanMates', 'population', 'males', 'females', 'offspring',
#        'offspring_desired', 'offspring_realized', 'offspring_dropped', 'Rep',
#        'TotalOffspringBorn'],
#       dtype='object')

# %%
Fish = df[['MeanRSC','MeanMates','males','females','population','Generation', 'Rep']]
Fish.head(20)
# Out:
#      MeanRSC  MeanMates  males  females  population  Generation  Rep
# 0   3.810000   3.145000  200.0    200.0       400.0         1.0  1.0
# 1   4.093931   3.236443  478.0    461.0       939.0         2.0  1.0
# 2   4.282459   3.486000  500.0    500.0      1000.0         3.0  1.0
# 3   4.539119   3.768000  500.0    500.0      1000.0         4.0  1.0
# 4   4.633623   3.728000  500.0    500.0      1000.0         5.0  1.0
# 5   4.877454   3.756000  500.0    500.0      1000.0         6.0  1.0
# 6   5.133563   3.910000  500.0    500.0      1000.0         7.0  1.0
# 7   5.299288   3.942000  500.0    500.0      1000.0         8.0  1.0
# 8   5.525984   4.028000  500.0    500.0      1000.0         9.0  1.0
# 9   5.699900   4.040000  500.0    500.0      1000.0        10.0  1.0
# 10  4.175000   3.230000  200.0    200.0       400.0         1.0  2.0
# 11  4.466188   3.482255  478.0    479.0       957.0         2.0  2.0
# 12  4.647263   3.656000  500.0    500.0      1000.0         3.0  2.0
# 13  4.911646   3.656000  500.0    500.0      1000.0         4.0  2.0
# 14  5.080081   4.014000  500.0    500.0      1000.0         5.0  2.0
# 15  5.248404   4.018000  500.0    500.0      1000.0         6.0  2.0
# 16  5.695563   4.022000  500.0    500.0      1000.0         7.0  2.0
# 17  5.981140   4.038000  500.0    500.0      1000.0         8.0  2.0
# 18  6.159340   4.124000  500.0    500.0      1000.0         9.0  2.0
# 19  6.174191   4.168000  500.0    500.0      1000.0        10.0  2.0

# %%
sns.scatterplot(data=df, x='MeanRSC', y='offspring', hue='Rep')
# Out:
# <Axes: xlabel='MeanRSC', ylabel='offspring'>

# %%
sns.lineplot(data=df, x='Generation', y='offspring', hue='Rep')
# Out:
# <Axes: xlabel='Generation', ylabel='offspring'>

# %%
sns.lineplot(data=df, x='MeanMates', y='MeanRSC', hue='Rep')
# Out:
# <Axes: xlabel='MeanMates', ylabel='MeanRSC'>

# %%
correlation_value = df["MeanRSC"].corr(df["MeanMates"])
correlation_value2 = df["MeanRSC"].corr(df["offspring"])
print("Correlation between MeanRSC and MeanMates:", correlation_value)
print("Correlation between MeanRSC and Offspring:", correlation_value2)
# Out:
# Correlation between MeanRSC and MeanMates: 0.9418075147923796
# Correlation between MeanRSC and Offspring: 0.7934812477621339
