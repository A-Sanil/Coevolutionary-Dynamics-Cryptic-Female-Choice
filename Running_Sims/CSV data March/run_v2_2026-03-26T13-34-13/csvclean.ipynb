# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/aadityasanil/Desktop/Lab Testing Feb 19/Coevolutionary-Dynamics-Cryptic-Female-Choice/Running_Sims/CSV data March/run_v2_2026-03-26T13-34-13/kbuffer_v2_results_2026-03-26T13-34-13.csv")

# %%
print(df.columns)
# Out:
# Index(['MeanMale', 'MeanFemale', 'SDMale', 'SDFemale', 'cor', 'MeanCount',
#        'SDCount', 'is', 'int', 'BMale', 'GMale', 'BFemale', 'GFemale',
#        'BSperm', 'GSperm', 'GMF', 'GMS', 'GFS', 'a', 'MeanRSC', 'Generation',
#        'MeanMates', 'population', 'males', 'females', 'offspring',
#        'offspring_desired', 'offspring_realized', 'offspring_dropped', 'Rep',
#        'TotalOffspringBorn'],
#       dtype='object')

# %%
Fish = df[['MeanRSC','MeanMates','males','females','population','Generation', 'Rep']]
Fish.head(20)
# Out:
#      MeanRSC  MeanMates  males  females  population  Generation  Rep
# 0   3.880000   3.300000  200.0    200.0       400.0         1.0  1.0
# 1   4.178219   3.460194  469.0    515.0       984.0         2.0  1.0
# 2   4.448972   3.592000  500.0    500.0      1000.0         3.0  1.0
# 3   4.701801   3.644000  500.0    500.0      1000.0         4.0  1.0
# 4   5.002654   3.836000  500.0    500.0      1000.0         5.0  1.0
# 5   5.218895   3.840000  500.0    500.0      1000.0         6.0  1.0
# 6   5.434075   4.142000  500.0    500.0      1000.0         7.0  1.0
# 7   5.729034   4.130000  500.0    500.0      1000.0         8.0  1.0
# 8   5.862836   4.090000  500.0    500.0      1000.0         9.0  1.0
# 9   6.175133   4.232000  500.0    500.0      1000.0        10.0  1.0
# 10  6.359838   4.276000  500.0    500.0      1000.0        11.0  1.0
# 11  6.601343   4.418000  500.0    500.0      1000.0        12.0  1.0
# 12  6.512090   4.402000  500.0    500.0      1000.0        13.0  1.0
# 13  6.711364   4.328000  500.0    500.0      1000.0        14.0  1.0
# 14  6.861848   4.438000  500.0    500.0      1000.0        15.0  1.0
# 15  7.155379   4.410000  500.0    500.0      1000.0        16.0  1.0
# 16  7.412011   4.504000  500.0    500.0      1000.0        17.0  1.0
# 17  7.469783   4.456000  500.0    500.0      1000.0        18.0  1.0
# 18  7.614093   4.458000  500.0    500.0      1000.0        19.0  1.0
# 19  7.747652   4.474000  500.0    500.0      1000.0        20.0  1.0

# %%
sns.scatterplot(data=df, x='MeanRSC', y='offspring', hue='Rep')
# Out:
# <Axes: xlabel='MeanRSC', ylabel='offspring'>

# %%
sns.lineplot(data=df, x='Generation', y='offspring')
# Out:
# <Axes: xlabel='Generation', ylabel='offspring'>

# %%
sns.lineplot(data=df, x='MeanMates', y='MeanRSC', hue='Rep')
# Out:
# <Axes: xlabel='MeanMates', ylabel='MeanRSC'>

# %%
correlation_value = df["MeanRSC"].corr(df["MeanMates"])
correlation_value2 = df["MeanRSC"].corr(df["offspring"])
print("Correlation between MeanRSC and MeanMates:", correlation_value)
print("Correlation between MeanRSC and Offspring:", correlation_value2)
# Out:
# Correlation between MeanRSC and MeanMates: 0.9463780927264477
# Correlation between MeanRSC and Offspring: 0.6069564942747302
