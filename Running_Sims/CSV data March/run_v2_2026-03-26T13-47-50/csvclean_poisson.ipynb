# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/aadityasanil/Desktop/Lab Testing Feb 19/Coevolutionary-Dynamics-Cryptic-Female-Choice/Running_Sims/CSV data/run_2026-02-26T10-47-46/kbuffer_results_2026-02-26T10-47-46.csv")

# %%
print(df.columns)
# Out:
# Index(['MeanMale', 'MeanFemale', 'SDMale', 'SDFemale', 'cor', 'MeanCount',
#        'SDCount', 'is', 'int', 'BMale', 'GMale', 'BFemale', 'GFemale',
#        'BSperm', 'GSperm', 'GMF', 'GMS', 'GFS', 'a', 'MeanRSC', 'Generation',
#        'MeanMates', 'population', 'males', 'females', 'offspring', 'Rep'],
#       dtype='object')

# %%
Fish = df[['MeanRSC','MeanMates','males','females','population','Generation', 'Rep']]
Fish.head(20)
# Out:
#      MeanRSC  MeanMates    males  females  population  Generation  Rep
# 0   4.016000   4.047000   1000.0   1000.0      2000.0         1.0  1.0
# 1   4.084404   3.936656   1926.0   1926.0      3852.0         2.0  1.0
# 2   4.104435   4.083740   3690.0   3690.0      7380.0         3.0  1.0
# 3   4.155334   4.121327   7113.0   7113.0     14226.0         4.0  1.0
# 4   4.181850   4.186294  13731.0  13731.0     27462.0         5.0  1.0
# 5   4.237836   4.239067  26570.0  26570.0     53140.0         6.0  1.0
# 6   4.277886   4.256420  50000.0  50000.0    100000.0         7.0  1.0
# 7   4.308213   4.319340  50000.0  50000.0    100000.0         8.0  1.0
# 8   4.343849   4.354700  50000.0  50000.0    100000.0         9.0  1.0
# 9   4.391375   4.372960  50000.0  50000.0    100000.0        10.0  1.0
# 10  4.421940   4.406060  50000.0  50000.0    100000.0        11.0  1.0
# 11  4.451671   4.456600  50000.0  50000.0    100000.0        12.0  1.0
# 12  4.486706   4.486420  50000.0  50000.0    100000.0        13.0  1.0
# 13  4.525874   4.516160  50000.0  50000.0    100000.0        14.0  1.0
# 14  4.545220   4.540220  50000.0  50000.0    100000.0        15.0  1.0
# 15  4.568161   4.587320  50000.0  50000.0    100000.0        16.0  1.0
# 16  4.611090   4.607460  50000.0  50000.0    100000.0        17.0  1.0
# 17  4.634446   4.648600  50000.0  50000.0    100000.0        18.0  1.0
# 18  4.677273   4.680880  50000.0  50000.0    100000.0        19.0  1.0
# 19  4.703575   4.713960  50000.0  50000.0    100000.0        20.0  1.0

# %%
sns.scatterplot(data=df, x='MeanRSC', y='offspring', hue='Rep')
# Out:
# <Axes: xlabel='MeanRSC', ylabel='offspring'>

# %%
sns.lineplot(data=df, x='Generation', y='offspring', hue='Rep')
# Out:
# <Axes: xlabel='Generation', ylabel='offspring'>

# %%
sns.lineplot(data=df, x='MeanMates', y='MeanRSC', hue='Rep')
# Out:
# <Axes: xlabel='MeanMates', ylabel='MeanRSC'>

# %%
correlation_value = df["MeanRSC"].corr(df["MeanMates"])
correlation_value2 = df["MeanRSC"].corr(df["offspring"])
print("Correlation between MeanRSC and MeanMates:", correlation_value)
print("Correlation between MeanRSC and Offspring:", correlation_value2)
# Out:
# Correlation between MeanRSC and MeanMates: 0.9994947817074137
# Correlation between MeanRSC and Offspring: 0.5245573221122619
