# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/aadityasanil/Desktop/Lab Testing Feb 19/Coevolutionary-Dynamics-Cryptic-Female-Choice/Running_Sims/CSV data March/run_v2_2026-03-26T13-48-55/kbuffer_v2_results_2026-03-26T13-48-55.csv")

# %%
print(df.columns)
# Out:
# Index(['MeanMale', 'MeanFemale', 'SDMale', 'SDFemale', 'cor', 'MeanCount',
#        'SDCount', 'is', 'int', 'BMale', 'GMale', 'BFemale', 'GFemale',
#        'BSperm', 'GSperm', 'GMF', 'GMS', 'GFS', 'a', 'MeanRSC', 'Generation',
#        'MeanMates', 'population', 'males', 'females', 'offspring',
#        'offspring_desired', 'offspring_realized', 'offspring_dropped', 'Rep',
#        'TotalOffspringBorn'],
#       dtype='object')

# %%
Fish = df[['MeanRSC','MeanMates','males','females','population','Generation', 'Rep']]
Fish.head(20)
# Out:
#      MeanRSC  MeanMates  males  females  population  Generation  Rep
# 0   4.175000   3.190000  200.0    200.0       400.0         1.0  1.0
# 1   4.138901   3.295238  215.0    210.0       425.0         2.0  1.0
# 2   4.051946   3.239631  228.0    217.0       445.0         3.0  1.0
# 3   4.048408   3.155172  242.0    232.0       474.0         4.0  1.0
# 4   3.975485   3.384000  254.0    250.0       504.0         5.0  1.0
# 5   3.923210   3.295019  271.0    261.0       532.0         6.0  1.0
# 6   3.826801   3.233577  289.0    274.0       563.0         7.0  1.0
# 7   3.742757   3.027211  308.0    294.0       602.0         8.0  1.0
# 8   3.674942   3.050955  332.0    314.0       646.0         9.0  1.0
# 9   3.615315   3.104651  353.0    344.0       697.0        10.0  1.0
# 10  3.525120   3.118598  379.0    371.0       750.0        11.0  1.0
# 11  3.510891   2.953964  405.0    391.0       796.0        12.0  1.0
# 12  3.454188   2.808511  426.0    423.0       849.0        13.0  1.0
# 13  3.405938   2.864924  460.0    459.0       919.0        14.0  1.0
# 14  3.338874   2.903226  500.0    496.0       996.0        15.0  1.0
# 15  3.286067   2.858000  500.0    500.0      1000.0        16.0  1.0
# 16  3.245634   2.810000  500.0    500.0      1000.0        17.0  1.0
# 17  3.139191   2.740000  500.0    500.0      1000.0        18.0  1.0
# 18  3.112260   2.842000  500.0    500.0      1000.0        19.0  1.0
# 19  3.067687   2.706000  500.0    500.0      1000.0        20.0  1.0

# %%
sns.scatterplot(data=df, x='MeanRSC', y='offspring', hue='Rep')
# Out:
# <Axes: xlabel='MeanRSC', ylabel='offspring'>

# %%
 
sns.lineplot(data=df, x='Generation', y='offspring', hue='Rep')
# Out:
# <Axes: xlabel='Generation', ylabel='offspring'>

# %%
correlation_value = df["MeanRSC"].corr(df["MeanMates"])
correlation_value2 = df["MeanRSC"].corr(df["offspring"])
print("Correlation between MeanRSC and MeanMates:", correlation_value)
print("Correlation between MeanRSC and Offspring:", correlation_value2)
# Out:
# Correlation between MeanRSC and MeanMates: 0.9994947817074137
# Correlation between MeanRSC and Offspring: 0.5245573221122619
