# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/aadityasanil/Desktop/Lab Testing Feb 19/Coevolutionary-Dynamics-Cryptic-Female-Choice/Running_Sims/CSV data/run_2026-02-20T14-31-21/kbuffer_one_run_2026-02-20T14-31-21.csv")

# %%
print(df.columns)
# Out:
# Index(['MeanMale', 'MeanFemale', 'SDMale', 'SDFemale', 'cor', 'MeanCount',
#        'SDCount', 'is', 'int', 'BMale', 'GMale', 'BFemale', 'GFemale',
#        'BSperm', 'GSperm', 'GMF', 'GMS', 'GFS', 'a', 'MeanRSC', 'Generation',
#        'MeanMates', 'population', 'males', 'females', 'Rep'],
#       dtype='object')

# %%
Fish = df[['MeanRSC','MeanMates','males','females','population','Generation', 'Rep']]
Fish.head(10)
# Out:
#     MeanRSC  MeanMates    males  females  population  Generation  Rep
# 0  4.080000   3.710000    100.0    100.0       200.0         1.0  1.0
# 1  4.177991   4.047619    189.0    189.0       378.0         2.0  1.0
# 2  4.254123   3.958791    364.0    364.0       728.0         3.0  1.0
# 3  4.297850   4.392908    705.0    705.0      1410.0         4.0  1.0
# 4  4.384335   4.355263   1368.0   1368.0      2736.0         5.0  1.0
# 5  4.441095   4.406990   2661.0   2661.0      5322.0         6.0  1.0
# 6  4.497220   4.478824   5171.0   5171.0     10342.0         7.0  1.0
# 7  4.519817   4.503479  10060.0  10060.0     20120.0         8.0  1.0
# 8  4.554305   4.527837  19614.0  19614.0     39228.0         9.0  1.0
# 9  4.653353   4.633450  20000.0  20000.0     40000.0        10.0  1.0

# %%
sns.lineplot(data=df, x='Generation', y='population', hue='Rep')
# Out:
# <Axes: xlabel='Generation', ylabel='MeanRSC'>

# %%
sns.lineplot(data=df, x='Generation', y='MeanRSC', hue='Rep')
# Out:
# <Axes: xlabel='Generation', ylabel='MeanRSC'>
