# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/aadityasanil/Desktop/Lab Testing Feb 19/Coevolutionary-Dynamics-Cryptic-Female-Choice/Running_Sims/CSV data/run_2026-02-20T15-10-23/kbuffer_one_run_2026-02-20T15-10-23.csv")

# %%
print(df.columns)
# Out:
# Index(['MeanMale', 'MeanFemale', 'SDMale', 'SDFemale', 'cor', 'MeanCount',
#        'SDCount', 'is', 'int', 'BMale', 'GMale', 'BFemale', 'GFemale',
#        'BSperm', 'GSperm', 'GMF', 'GMS', 'GFS', 'a', 'MeanRSC', 'Generation',
#        'MeanMates', 'population', 'males', 'females', 'Rep'],
#       dtype='object')

# %%
Fish = df[['MeanRSC','MeanMates','males','females','population','Generation', 'Rep']]
Fish.head(20)
# Out:
#      MeanRSC  MeanMates  males  females  population  Generation  Rep
# 0   3.910000   4.480000  100.0    100.0       200.0         1.0  1.0
# 1   4.205741   4.238342  193.0    193.0       386.0         2.0  1.0
# 2   4.107692   4.178667  375.0    375.0       750.0         3.0  1.0
# 3   4.124658   4.152000  500.0    500.0      1000.0         4.0  1.0
# 4   4.165468   4.140000  500.0    500.0      1000.0         5.0  1.0
# 5   4.227630   4.090000  500.0    500.0      1000.0         6.0  1.0
# 6   4.319102   4.158000  500.0    500.0      1000.0         7.0  1.0
# 7   4.452449   4.430000  500.0    500.0      1000.0         8.0  1.0
# 8   4.596264   4.222000  500.0    500.0      1000.0         9.0  1.0
# 9   4.726613   4.552000  500.0    500.0      1000.0        10.0  1.0
# 10  4.789717   4.754000  500.0    500.0      1000.0        11.0  1.0
# 11  4.950659   4.542000  500.0    500.0      1000.0        12.0  1.0
# 12  4.791157   4.870000  500.0    500.0      1000.0        13.0  1.0
# ...

# %%
sns.lineplot(data=df, x='Generation', y='population', hue='Rep')
# Out:
# <Axes: xlabel='Generation', ylabel='population'>

# %%
sns.lineplot(data=df, x='Generation', y='MeanRSC', hue='Rep')
# Out:
# <Axes: xlabel='Generation', ylabel='MeanRSC'>
