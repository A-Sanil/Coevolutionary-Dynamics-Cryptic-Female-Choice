# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/aadityasanil/Desktop/Lab Testing Feb 19/Coevolutionary-Dynamics-Cryptic-Female-Choice/Running_Sims/CSV data/run_2026-02-20T15-40-41/kbuffer_results_2026-02-20T15-40-41.csv")

# %%
print(df.columns)
# Out:
# Index(['MeanMale', 'MeanFemale', 'SDMale', 'SDFemale', 'cor', 'MeanCount',
#        'SDCount', 'is', 'int', 'BMale', 'GMale', 'BFemale', 'GFemale',
#        'BSperm', 'GSperm', 'GMF', 'GMS', 'GFS', 'a', 'MeanRSC', 'Generation',
#        'MeanMates', 'population', 'males', 'females', 'offspring', 'Rep'],
#       dtype='object')

# %%
Fish = df[['MeanRSC','MeanMates','males','females','population','Generation', 'Rep']]
Fish.head(20)
# Out:
#      MeanRSC  MeanMates   males  females  population  Generation  Rep
# 0   4.190000   4.090000   100.0    100.0       200.0         1.0  1.0
# 1   4.164545   3.917526   194.0    194.0       388.0         2.0  1.0
# 2   4.109226   4.021680   369.0    369.0       738.0         3.0  1.0
# 3   4.058423   3.971711   707.0    707.0      1414.0         4.0  1.0
# 4   4.110918   4.101099  1365.0   1365.0      2730.0         5.0  1.0
# 5   4.112939   4.094261  2631.0   2631.0      5262.0         6.0  1.0
# 6   4.140959   4.164000  5000.0   5000.0     10000.0         7.0  1.0
# 7   4.189196   4.169400  5000.0   5000.0     10000.0         8.0  1.0
# 8   4.235136   4.230200  5000.0   5000.0     10000.0         9.0  1.0
# 9   4.268390   4.276200  5000.0   5000.0     10000.0        10.0  1.0
# 10  4.287489   4.257200  5000.0   5000.0     10000.0        11.0  1.0
# 11  4.285186   4.339800  5000.0   5000.0     10000.0        12.0  1.0
# ...

# %%
sns.lineplot(data=df, x='Generation', y='population', hue='Rep')
# Out:
# <Axes: xlabel='Generation', ylabel='population'>

# %%
sns.lineplot(data=df, x='Generation', y='offspring')
# Out:
# <Axes: xlabel='Generation', ylabel='offspring'>
